# %%
import pandas as pd

# %%
df=pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
questions = [
    "Hii / Hi",
    "Hello!",
    "Hi, who are you",
    "How are you",
    "What can you do",
    "How can I apply for admission",
    "What courses are offered at IIIT Nagpur",
    "What is the eligibility for B.Tech at IIIT Nagpur",
    "Where is IIIT Nagpur located",
    "What facilities are available on campus",
    "Does the campus have hostel facilities",
    "How are the placements at IIIT Nagpur",
    "Are internships mandatory",
    "How can I contact IIIT Nagpur",
    "What are the office hours",
    "How can I get my transcripts",
    "Does IIIT Nagpur host any cultural events",
    "Is IIIT Nagpur government-funded",
    "What are the library timings",
    "Can alumni access campus facilities",
    "Hi there!",
    "Greetings!",
    "Who are you?",
    "Can you introduce yourself?",
    "How are you doing today?",
    "What are you capable of?",
    "Tell me what you can help with.",
    "How do I apply to IIIT Nagpur?",
    "What is the process for admission?",
    "What programs are available at IIIT Nagpur?",
    "Which courses does IIIT Nagpur offer?",
    "What is the eligibility criteria for B.Tech programs?",
    "Where is your campus located?",
    "Can you tell me the location of IIIT Nagpur?",
    "What amenities does the campus provide?",
    "Is there hostel accommodation on campus?",
    "Does IIIT Nagpur have hostels?",
    "How is the placement scenario at IIIT Nagpur?",
    "What are the placement stats for IIIT Nagpur?",
    "Do I need to complete an internship as part of the course?",
    "Are internships mandatory for students?",
    "How can I get in touch with IIIT Nagpur?",
    "What are the contact details for the institute?",
    "When is the administrative office open?",
    "What are the office working hours?",
    "How do I request my transcripts?",
    "What is the procedure to get academic transcripts?",
    "Does the institute conduct cultural or technical events?",
    "Are there any events or festivals organized?",
    "Is IIIT Nagpur funded by the government?",
    "What is the funding source of IIIT Nagpur?",
    "What are the library hours?",
    "When is the library accessible to students?",
    "Can former students use the facilities?",
    "Are alumni allowed to access the campus resources?",
    "Disha",
    "maker who created",
    "supervisor",
    "year of creation",
    "creator"
]

# %%
df["Name"]=questions

# %%
df
# Out:
#                                                  Name
# 0                                            Hii / Hi
# 1                                              Hello!
# 2                                     Hi, who are you
# 3                                         How are you
# 4                                     What can you do
# 5                       How can I apply for admission
# 6             What courses are offered at IIIT Nagpur
# 7   What is the eligibility for B.Tech at IIIT Nagpur
# 8                        Where is IIIT Nagpur located
# 9             What facilities are available on campus
# 10             Does the campus have hostel facilities
# 11              How are the placements at IIIT Nagpur
# 12                          Are internships mandatory
# 13                      How can I contact IIIT Nagpur
# 14                          What are the office hours
# 15                       How can I get my transcripts
# ...

# %%
answers = [
    "Hi! Welcome to the IIIT Nagpur chatbot. How can I assist you today",
    "Hi! Welcome to the IIIT Nagpur chatbot. How can I assist you today",
    "I am Disha, the chatbot for IIIT Nagpur. Made by\n- Gyanbardhan\n- Lakshit Upreti\n- Abhishek Kumar\nI am here to answer your questions and guide you.",
    "I am just a chatbot, but I am here and ready to help you!",
    "I can help you with information about IIIT Nagpur, faculties, courses, admissions, campus life, contact details, and more. Just ask me!",
    "Admissions to IIIT Nagpur are through the JEE Main examination. Check the official site for details: iiitn.ac.in.",
    "We offer \n- B. Tech. Computer Science & Engineering\n- B. Tech. CSE (Artiﬁcial Intelligence & Machine Learning)\n- B. Tech. CSE (Data Science & Analytics)\n- B. Tech. CSE (Human Computer Interaction & Gaming Technology)\n- B. Tech. Electronics & Communication Engineering\n- B. Tech. ECE (Internet of Things)\n- Ph.D. programs.",
    "You need to qualify for JEE Main and meet the cut-off for IIIT Nagpur during JoSAA/CSAB counseling.",
    "IIIT Nagpur is located at Survey No. 140,141/1 behind Br. Sheshrao Wankhade Shetkari Sahkari Soot Girni, Village - Waranga, PO - Dongargaon (Butibori), Tahsil- Nagpur (Rural), District Nagpur, Maharashtra- 441108",
    "The campus offers hostels, a library, computer labs, sports facilities, and high-speed internet, among other amenities.",
    "Yes, IIIT Nagpur provides hostel facilities for both boys and girls.",
    "IIIT Nagpur has a strong placement record, with top recruiters like LandingKart ,Mastersoft ,Samsung R&D ,Nvidia, TCS, Infosys, and many more visiting the campus.",
    "Yes, internships (at least 1 semester 7th or 8th) are an integral part of the curriculum to provide practical exposure.",
    "You can \naddress - \"Permanent Address: Survey No. 140,141/1 behind Br. Sheshrao Wankhade Shetkari Sahkari Soot Girni, Village - Waranga, PO - Dongargaon (Butibori), Tahsil- Nagpur (Rural), District Nagpur, Maharashtra- 441108\"\nemail us at registrar@iiitn.ac.in \ncall us at 9405215010.",
    "The administrative office operates from Monday through Friday from 9 AM to 5:30 PM, and it is closed on Saturday and Sunday.",
    "Transcripts can be requested from the Academic Office. Contact the office or check the website for the procedure.",
    "Yes, IIIT Nagpur organizes cultural fests - Abhivyakti, technical events - Tantrafaesta, sports - Kshitij, and hackathons.",
    "Yes, IIIT Nagpur is an Institute of National Importance, established by the Ministry of Education (MoE), Government of India.",
    "The library is open \nLibrary Timing:\nMonday to Friday : 8:00 AM to 06:00 PM\nSaturday : 09:30 AM to 06:00 PM\nCirculation Timing : 08:30 AM to 05:30 PM\nReading Room:\nMonday to Friday : 8:00 AM to 09:00 PM\nSaturday to Sunday : 09:30 AM to 09:00 PM",
    "Yes, alumni can visit and access some campus facilities with prior permission.",
    "Hi! Welcome to the IIIT Nagpur chatbot. How may I assist you today?",
    "Hello! This is the IIIT Nagpur chatbot. Feel free to ask me anything about the institute!",
    "I’m Disha, your friendly IIIT Nagpur chatbot, here to help you with your queries!",
    "I am Disha, created by Gyanbardhan, Lakshit Upreti, and Abhishek Kumar. Let me guide you!",
    "I’m doing great, thank you! How can I assist you today?",
    "I’m a chatbot designed to assist with IIIT Nagpur information and FAQs.",
    "I can answer questions about IIIT Nagpur’s courses, admissions, faculty, and more!",
    "Admissions to IIIT Nagpur are based on JEE Main scores. Visit iiitn.ac.in for more details.",
    "The admission process involves JEE Main qualification and meeting the cutoff during counseling.",
    "IIIT Nagpur offers various B.Tech programs and Ph.D. courses in engineering and technology.",
    "Our courses include Computer Science, AI & ML, Data Science, HCI & Gaming, and IoT.",
    "To enroll in B.Tech programs, you must qualify JEE Main and participate in JoSAA/CSAB counseling.",
    "IIIT Nagpur is located at Survey No. 140,141/1 behind Br. Sheshrao Wankhade Shetkari Sahkari Soot Girni, Village - Waranga, PO - Dongargaon (Butibori), Tahsil- Nagpur (Rural), District Nagpur, Maharashtra- 441108",
    "The institute is located in the rural Nagpur area near Dongargaon (Butibori).",
    "The campus provides high-speed internet, a library, hostels, and recreational facilities.",
    "Yes, hostel facilities are available for both male and female students.",
    "Both boys' and girls' hostels are available, offering all basic amenities.",
    "Placements at IIIT Nagpur are excellent, with top recruiters visiting every year.",
    "IIIT Nagpur has a strong placement record, with top recruiters like LandingKart ,Mastersoft ,Samsung R&D ,Nvidia, TCS, Infosys, and many more visiting the campus.",
    "Internships are compulsory, typically completed in the 7th or 8th semester.",
    "Yes, internships are an essential part of the curriculum to provide industry exposure.",
    "You can email registrar@iiitn.ac.in or call 9405215010 to contact us.",
    "Feel free to reach out via email or phone, or visit the campus at MIHAN SEZ, Nagpur.",
    "The office operates from Monday to Friday, 9:00 AM to 5:30 PM.",
    "Administrative working hours are 9:00 AM to 5:30 PM on weekdays, excluding weekends.",
    "Visit the Academic Office or check our website for transcript request details.",
    "To get transcripts, you must contact the Academic Office or use the online request system.",
    "IIIT Nagpur hosts events like Abhivyakti (cultural), Tantrafaesta (technical), and Kshitij (sports).",
    "The institute organizes cultural fests, technical fests, sports events, and hackathons.",
    "Yes, IIIT Nagpur is a government-funded Institute of National Importance.",
    "The institute is funded and managed by the Ministry of Education, Government of India.",
    "The library is open Monday to Friday from 8:00 AM to 6:00 PM and on Saturdays until 6:00 PM.",
    "You can access the reading room even during weekends, from 9:30 AM to 9:00 PM.",
    "Alumni can visit and use some facilities with prior approval from the administration.",
    "Yes, former students are welcome on campus with appropriate permissions.",
    "Disha is IIIT Nagpur chatbot. How can I assist you today . Made by\n- Gyanbardhan\n- Lakshit Upreti\n- Abhishek Kumar\nI am here to answer your questions and guide you.",
    "I am Disha, the chatbot for IIIT Nagpur. Made/Created by\n- Gyanbardhan\n- Lakshit Upreti\n- Abhishek Kumar\nI am here to answer your questions and guide you.",
    "I am Disha, the chatbot for IIIT Nagpur. Made/Created by\n- Gyanbardhan\n- Lakshit Upreti\n- Abhishek Kumar Supervised by Dr. Mangesh Ramaji Kose",
    "August-2024 to December-2024",
    "Gyanbardhan",
]

# %%
df["Details"]=answers

# %%
df
# Out:
#                                                  Name  \
# 0                                            Hii / Hi
# 1                                              Hello!
# 2                                     Hi, who are you
# 3                                         How are you
# 4                                     What can you do
# 5                       How can I apply for admission
# 6             What courses are offered at IIIT Nagpur
# 7   What is the eligibility for B.Tech at IIIT Nagpur
# 8                        Where is IIIT Nagpur located
# 9             What facilities are available on campus
# 10             Does the campus have hostel facilities
# 11              How are the placements at IIIT Nagpur
# 12                          Are internships mandatory
# 13                      How can I contact IIIT Nagpur
# 14                          What are the office hours
# 15                       How can I get my transcripts
# ...

# %%
df.to_csv("new.csv")
